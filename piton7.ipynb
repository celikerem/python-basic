# %% [markdown]
# #VERİ TÜRLERİ

# %%
# 1) string  -->  yazı
# 2) float   -->  ondalıklı sayı
# 3) integer -->  tam sayı
# 4) bool    -->  boolean değerler true ya da false değerlerdi

# %% [markdown]
# #bool veri tipi

# %%
#True ya da false değerlere bool değerleri denir
#birtakım aritmetik operatörleri öğrenmiştik(+ - / * ** //)
#şimdi de karşılaştırma operatörlerini öğreneceğiz.

# %% [markdown]
# ## karşılaştırma opreatörleri

# %%
# ==  --> eşittir anlamına gelir.
# !=  --> eşit değildir anlamına gelir.
# >   --> büyüktür işareti
# <   --> küçüktür işareti
# >=  --> büyük eşittir
# <=  --> küçük eşittir

# karşılaştırma operatörlerinin sonunda True ya da False şeklinde bir bool değer döner

# %%
5 == 5
# Out:
# True

# %%
7 == 4
# Out:
# False

# %%
6 != 6
# Out:
# False

# %%
3 > 1
# Out:
# True

# %%
45 == 3
# Out:
# False

# %%
4 <= 4
# Out:
# True

# %%
1 >= 5
# Out:
# False

# %%
5 >= 5
# Out:
# True

# %% [markdown]
# ## mantıksal operatörler

# %%
# and, or, not olmak üzere üç tanedir
# mantıksal operaötrleri kullanırken yazacağımız karşılaştırma ifadelerini parantez içinde yazarız

# %% [markdown]
# ### and

# %%
#annd ve anlamına gelir
# and operatörünün iki taraf da True değerindeyse true verir. diğer kombinasyonlarda False verir

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
z = 6==6
y = 5!=6
z and y
# Out:
# True

# %%
(5==5) and (3>8)
# Out:
# False

# %%
(8>=8) and (1333<41)
# Out:
# False

# %%
(9 >= 2) and (50<=50)
# Out:
# True

# %% [markdown]
# ### or

# %%
# or, veya anlamına gelir.
# or operatöründe taraflardan en az 1'inin True olması, True olmasına yeterlidir.

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
(5==5) or (3>1000)
# Out:
# True
