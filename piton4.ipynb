# %%
#soru: x değişkenine istediğiniz bir int sayıyı y değişkenine istediğiniz bir float sayıyıy z değişkenine istediğiniz bir string ifadeyi atayın
#xi yyi zyi print ile alt alta yazdırın

x = 3
y = 4.2
z = "kerem"
print(x)
print(y)
print(z)
# Out:
# 3
# 4.2
# kerem

# %% [markdown]
# #len() fonksiyonu

# %%
#length kelimesinden gelir.
#len() fonksiyonu string ifadelerin karakter uzunluğunu ölçer.
# int ve float idalerein karakter uzunluğu ölçülemez.

# %%
len("türkiye")
# Out:
# 7

# %%
len("kısa bir cümle")
# Out:
# 14

# %%
len(59147)

# %%
len("59147")
# Out:
# 5

# %%
#soru
len("100 - 20")
# Out:
# 8

# %%
cümle_kısa = "rize merker"
cümle_uzun = "türkiye dünya kupasında 3. olmuştur"

print(len(cümle_kısa))
len(cümle_uzun)
# Out:
# 11
# 35

# %%
len(cümle_kısa) + len(cümle_uzun)
# Out:
# 46

# %%
cümle1 = "müslüman güvenilir kişidir"
cümle2 = "insanlara merhamet edene, Allah da merhamet eder"


len(cümle2) + len(cümle1)
# Out:
# 74

# %% [markdown]
# # type() fonksiyonu

# %%
#type fonksiyonu ifademizin veri tipinin ne olduğunu söyler.
#type ingilizce tip demek. yani bize ifademizin tipini verir.

# %%
type(15)
# Out:
# int

# %%
type(34.2)
# Out:
# float

# %%
type("ağrı dağı")
# Out:
# str

# %%
type("567")
# Out:
# str

# %%
sayi1 = 872
sayi2 = 12.4
isim = "murat"

type(isim),type(sayi2),type(sayi1)
# Out:
# (str, float, int)

# %%
#soru

a=147
b="147"

#ifadeleri arasında herhangi bir fark var mıdır?
# Out:
# '147'

# %%
a
# Out:
# 147

# %%
b
# Out:
# '147'

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
a + 3
# Out:
# 150

# %%
b + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-0e30423ba4f6> in <cell line: 1>()
# ----> 1 b + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
a * 3
# Out:
# 441

# %%
b * 3
# Out:
# '147147147'

# %%
#soru: a = 50 atamasını yapalım ve a değişkeninin tipine bakalım. sonra a değişkenini 2,5 ile çarparak tekrar a ya atayalım. oluşan yeni a nın tipine bakalkım.

a = 50
type(a)
# Out:
# int

# %%
a = a*2.5
type(a)
# Out:
# float

# %%
# x değişkenine 100 atamasını yapalım ardından xin 6 katını xe ata ve xi ekrana bastır
x = 100

# %%
x = x*6

# %%
x
# Out:
# 600

# %%
#y değişkenine 10 atamsını yapalım ardından ynin 3.5 katını tekrar y değişkenine atayalım
y = 10
y
# Out:
# 10

# %%
y = y*3.5
y
# Out:
# 35.0

# %%
#xe 4 değişkenini ata yye 11 değişkenini ata zye xin 3 ynin 2 katının toplamını ata. son durumda z ye z nin 5 katını atayarak ekrana yazdır

x = 4
y = 11
z = x*3 + y*2
print(z)
z = z*5
z
# Out:
# 34
# 170

# %%
#bitti
